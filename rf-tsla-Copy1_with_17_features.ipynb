# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, ConfusionMatrixDisplay,  classification_report
)

# %%
tsla  = pd.read_csv('data/tsla_features.csv',  parse_dates=['date'], index_col='date').sort_index()

# %%
tsla.head()
# Out:
#             adj_close      close       high        low       open    volume  \
# date
# 2015-01-02  14.620667  14.620667  14.883333  14.217333  14.858000  71466000
# 2015-01-05  14.006000  14.006000  14.433333  13.810667  14.303333  80527500
# 2015-01-06  14.085333  14.085333  14.280000  13.614000  14.004000  93928500
# 2015-01-07  14.063333  14.063333  14.318667  13.985333  14.223333  44526000
# 2015-01-08  14.041333  14.041333  14.253333  14.000667  14.187333  51637500
#
#             daily_return  weekly_return       ma_7      ma_21  ...  \
# date                                                           ...
# 2015-01-02     -0.013938      -0.013273  14.863905  14.497746  ...
# 2015-01-05     -0.042041      -0.077825  14.760286  14.436762  ...
# 2015-01-06      0.005664      -0.063932  14.655714  14.382794  ...
# 2015-01-07     -0.001562      -0.050758  14.495047  14.342286  ...
# 2015-01-08     -0.001564      -0.053010  14.351333  14.330413  ...
#
#             lag_return_5  month  quarter  season_num  season  \
# date
# 2015-01-02      0.005838      1        1           0  Winter
# 2015-01-05      0.025016      1        1           0  Winter
# 2015-01-06     -0.009262      1        1           0  Winter
# 2015-01-07     -0.015418      1        1           0  Winter
# 2015-01-08      0.000810      1        1           0  Winter
#
#             is_earnings_week        vix  is_major_event  target_direction  \
# date
# 2015-01-02                 0  17.790001               0                 0
# 2015-01-05                 0  19.920000               0                 1
# 2015-01-06                 0  21.120001               0                 0
# 2015-01-07                 0  19.309999               0                 0
# 2015-01-08                 0  17.010000               0                 0
#
#             target_return
# date
# 2015-01-02      -0.057681
# 2015-01-05      -0.037508
# 2015-01-06      -0.033273
# 2015-01-07      -0.086561
# 2015-01-08      -0.089023
#
# [5 rows x 35 columns]

# %%
FEATURES = [
    'daily_return', 'weekly_return', 'ma_cross', 'dist_from_ma21', 'daily_range',
    'rsi_14', 'macd_hist', 'bb_position', 'volatility_7', 'volatility_20',
    'volume_change', 'volume_ratio',
    'lag_return_1', 'lag_return_3', 'lag_return_5',
    'vix',
]
TARGET_CLS = 'target_direction'

# %%
tsla_cls  = tsla[FEATURES + [TARGET_CLS]].dropna().copy()

print(tsla_cls.shape)
# Out:
# (2515, 17)

# %%
def walk_forward_splits(df, train_window, test_window=42, embargo=5):
    """
    Generates (train_idx, test_idx) pairs for walk-forward validation.
    embargo = gap between train end and test start to prevent leakage
    from lagged features (lag_return_5, weekly_return, volatility_20 etc.)
    
    Fold 1: Train [0 → 62]  Gap [63 → 67]  Test [68 → 109]
    Fold 2: Train [42 → 104] Gap [105 → 109] Test [110 → 151]
    """
    splits = []
    n = len(df)
    start = 0

    while start + train_window + embargo + test_window <= n:
        train_start = start
        train_end   = start + train_window

        test_start  = train_end + embargo
        test_end    = test_start + test_window

        train_idx = list(range(train_start, train_end))
        test_idx  = list(range(test_start, test_end))

        splits.append((train_idx, test_idx))

        
        start += test_window

    return splits

# %%
tsla_folds = walk_forward_splits(tsla_cls, train_window = 189)
print("TSLA folds:", len(tsla_folds))
# Out:
# TSLA folds: 55

# %%
fold_scores = []
tsla_actual, tsla_pred = [], []
tsla_probs = []

# %%
all_importances = []

# %%
for i, (train_idx, test_idx) in enumerate(tsla_folds):
    X_train = tsla_cls.iloc[train_idx][FEATURES]
    y_train = tsla_cls.iloc[train_idx][TARGET_CLS]
    X_test  = tsla_cls.iloc[test_idx][FEATURES]
    y_test  = tsla_cls.iloc[test_idx][TARGET_CLS]

    rf = RandomForestClassifier(n_estimators=100, random_state=42, class_weight='balanced')
    rf.fit(X_train, y_train)

   
    y_p = rf.predict(X_test)
    y_prob = rf.predict_proba(X_test)[:, 1]

   
    cm = confusion_matrix(y_test, y_p, labels=[0, 1])
    tn, fp, fn, tp = cm.ravel()
    spec = tn / (tn + fp) if (tn + fp) > 0 else 0

    fold_scores.append({
        'accuracy': accuracy_score(y_test, y_p),
        'f1': f1_score(y_test, y_p, zero_division=0),
        'precision': precision_score(y_test, y_p, zero_division=0),
        'recall': recall_score(y_test, y_p, zero_division=0),
        'specificity': spec
    })

    tsla_actual.extend(y_test)
    tsla_pred.extend(y_p)
    tsla_probs.extend(y_prob)
    all_importances.append(rf.feature_importances_)

# %%
results_df = pd.DataFrame(fold_scores)
results_df
# Out:
#     accuracy        f1  precision    recall  specificity
# 0   0.619048  0.652174   0.600000  0.714286     0.523810
# 1   0.261905  0.205128   0.200000  0.210526     0.304348
# 2   0.452381  0.342857   0.857143  0.214286     0.928571
# 3   0.333333  0.391304   0.360000  0.428571     0.238095
# 4   0.595238  0.540541   0.588235  0.500000     0.681818
# 5   0.690476  0.723404   0.607143  0.894737     0.521739
# 6   0.357143  0.270270   0.263158  0.277778     0.416667
# 7   0.404762  0.137931   0.666667  0.076923     0.937500
# 8   0.476190  0.500000   0.578947  0.440000     0.529412
# 9   0.476190  0.388889   0.538462  0.304348     0.684211
# 10  0.476190  0.560000   0.500000  0.636364     0.300000
# 11  0.452381  0.510638   0.500000  0.521739     0.368421
# 12  0.476190  0.521739   0.444444  0.631579     0.347826
# 13  0.619048  0.555556   0.625000  0.500000     0.727273
# 14  0.357143  0.448980   0.343750  0.647059     0.160000
# 15  0.571429  0.550000   0.647059  0.478261     0.684211
# 16  0.428571  0.333333   0.352941  0.315789     0.521739
# 17  0.428571  0.428571   0.333333  0.600000     0.333333
# 18  0.380952  0.133333   0.400000  0.080000     0.823529
# 19  0.595238  0.514286   0.642857  0.428571     0.761905
# 20  0.571429  0.590909   0.541667  0.650000     0.500000
# 21  0.357143  0.400000   0.310345  0.562500     0.230769
# 22  0.476190  0.214286   0.600000  0.130435     0.894737
# 23  0.452381  0.410256   0.470588  0.363636     0.550000
# 24  0.428571  0.368421   0.538462  0.280000     0.647059
# 25  0.547619  0.536585   0.846154  0.392857     0.857143
# 26  0.380952  0.500000   0.406250  0.650000     0.136364
# 27  0.452381  0.342857   0.500000  0.260870     0.684211
# 28  0.523810  0.523810   0.611111  0.458333     0.611111
# 29  0.571429  0.689655   0.666667  0.714286     0.285714
# 30  0.547619  0.666667   0.558824  0.826087     0.210526
# 31  0.404762  0.545455   0.517241  0.576923     0.125000
# 32  0.476190  0.576923   0.441176  0.833333     0.208333
# 33  0.500000  0.322581   0.384615  0.277778     0.666667
# 34  0.380952  0.235294   0.363636  0.173913     0.631579
# 35  0.571429  0.709677   0.647059  0.785714     0.142857
# 36  0.380952  0.277778   0.500000  0.192308     0.687500
# 37  0.571429  0.571429   0.500000  0.666667     0.500000
# 38  0.452381  0.258065   0.500000  0.173913     0.789474
# 39  0.547619  0.577778   0.500000  0.684211     0.434783
# 40  0.523810  0.500000   0.769231  0.370370     0.800000
# 41  0.523810  0.629630   0.459459  1.000000     0.200000
# 42  0.452381  0.439024   0.428571  0.450000     0.454545
# 43  0.404762  0.418605   0.473684  0.375000     0.444444
# 44  0.404762  0.444444   0.400000  0.500000     0.318182
# 45  0.428571  0.294118   0.714286  0.185185     0.866667
# 46  0.357143  0.341463   0.333333  0.350000     0.363636
# 47  0.380952  0.380952   0.347826  0.421053     0.347826
# 48  0.595238  0.690909   0.633333  0.760000     0.352941
# 49  0.595238  0.585366   0.545455  0.631579     0.565217
# 50  0.523810  0.545455   0.500000  0.600000     0.454545
# 51  0.595238  0.638298   0.517241  0.833333     0.416667
# 52  0.476190  0.388889   0.700000  0.269231     0.812500
# 53  0.595238  0.604651   0.684211  0.541667     0.666667
# 54  0.595238  0.653061   0.592593  0.727273     0.450000

# %%
prob_df = pd.DataFrame({
    'actual': tsla_actual,
    'prob_up': tsla_probs

})

high_conviction_up = prob_df[prob_df['prob_up'] > 0.55]
high_conviction_down = prob_df[prob_df['prob_up'] < 0.45]

acc_up = (high_conviction_up['actual'] == 1).mean()
acc_down = (high_conviction_down['actual'] == 0).mean()

print(f"Accuracy when Prob > 0.55 (UP): {acc_up:.4f} (Samples: {len(high_conviction_up)})")
print(f"Accuracy when Prob < 0.45 (DOWN): {acc_down:.4f} (Samples: {len(high_conviction_down)})")
# Out:
# Accuracy when Prob > 0.55 (UP): 0.5100 (Samples: 804)
# Accuracy when Prob < 0.45 (DOWN): 0.4518 (Samples: 768)

# %%
results_df.describe()
# Out:
#         accuracy         f1  precision     recall  specificity
# count  55.000000  55.000000  55.000000  55.000000    55.000000
# mean    0.481818   0.465131   0.519130   0.483078     0.510947
# std     0.091868   0.150257   0.139536   0.224778     0.227765
# min     0.261905   0.133333   0.200000   0.076923     0.125000
# 25%     0.404762   0.355639   0.417411   0.292174     0.340580
# 50%     0.476190   0.500000   0.500000   0.478261     0.500000
# 75%     0.571429   0.574176   0.609127   0.648529     0.684211
# max     0.690476   0.723404   0.857143   1.000000     0.937500

# %%
avg_importance = np.mean(all_importances, axis=0)
feat_imp = pd.Series(avg_importance, index=FEATURES).sort_values(ascending=False)
feat_imp
# Out:
# lag_return_5      0.069857
# lag_return_3      0.069127
# daily_range       0.068189
# volatility_20     0.067539
# volume_change     0.066884
# vix               0.065157
# weekly_return     0.062760
# volume_ratio      0.062661
# volatility_7      0.061881
# lag_return_1      0.061414
# daily_return      0.060288
# macd_hist         0.058866
# rsi_14            0.058380
# ma_cross          0.058230
# bb_position       0.056911
# dist_from_ma21    0.051856
# dtype: float64

# %%
print(classification_report(tsla_actual, tsla_pred, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.46      0.49      0.48      1107
#            1       0.50      0.47      0.49      1203
#
#     accuracy                           0.48      2310
#    macro avg       0.48      0.48      0.48      2310
# weighted avg       0.48      0.48      0.48      2310

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=feat_imp.values, y=feat_imp.index)
plt.title("TSLA: Average Feature Importance (Default RF)")
plt.xlabel("Importance Score")
plt.show()

# %%
from itertools import product

n_estimators_values     = [100, 200, 500]
max_depth_values        = [4, 6, 8, 10, None]
min_samples_leaf_values = [1, 5, 10, 20]
max_features_values     = ['sqrt', 'log2']

combos = list(product(n_estimators_values, max_depth_values, min_samples_leaf_values, max_features_values))
print(f'Grid: {len(n_estimators_values)} n_estimators x {len(max_depth_values)} max_depth x {len(min_samples_leaf_values)} min_samples_leaf x {len(max_features_values)} max_features = {len(combos)} combinations')
print(f'Folds per combo: {len(tsla_folds)}')
print(f'Total RF fits: {len(combos) * len(tsla_folds)}')
# Out:
# Grid: 3 n_estimators x 5 max_depth x 4 min_samples_leaf x 2 max_features = 120 combinations
# Folds per combo: 55
# Total RF fits: 6600

# %%
grid_results = []

for n_est, max_d, min_leaf, max_feat in combos:
    fold_f1s, fold_accs, fold_precs, fold_recs, fold_specs = [], [], [], [], []

    for train_idx, test_idx in tsla_folds:
        X_train = tsla_cls.iloc[train_idx][FEATURES]
        y_train = tsla_cls.iloc[train_idx][TARGET_CLS]
        X_test  = tsla_cls.iloc[test_idx][FEATURES]
        y_test  = tsla_cls.iloc[test_idx][TARGET_CLS]

        rf = RandomForestClassifier(
            n_estimators=n_est, max_depth=max_d, min_samples_leaf=min_leaf,
            max_features=max_feat, class_weight='balanced', random_state=42, n_jobs=-1
        )
        rf.fit(X_train, y_train)
        y_pred = rf.predict(X_test)

        fold_f1s.append(f1_score(y_test, y_pred, zero_division=0))
        fold_accs.append(accuracy_score(y_test, y_pred))
        fold_precs.append(precision_score(y_test, y_pred, zero_division=0))
        fold_recs.append(recall_score(y_test, y_pred, zero_division=0))

        cm = confusion_matrix(y_test, y_pred, labels=[0, 1])
        tn, fp, fn, tp = cm.ravel()
        fold_specs.append(tn / (tn + fp) if (tn + fp) > 0 else 0.0)

    grid_results.append({
        'n_estimators': n_est, 'max_depth': max_d, 'min_samples_leaf': min_leaf,
        'max_features': max_feat, 'f1': np.mean(fold_f1s), 'accuracy': np.mean(fold_accs),
        'precision': np.mean(fold_precs), 'recall': np.mean(fold_recs), 'specificity': np.mean(fold_specs),
    })
    print(f'  n_est={n_est:>3}  depth={str(max_d):<5}  min_leaf={min_leaf:<3}  max_feat={max_feat:<5}  '
          f'F1={np.mean(fold_f1s):.3f}  acc={np.mean(fold_accs):.3f}  '
          f'prec={np.mean(fold_precs):.3f}  rec={np.mean(fold_recs):.3f}  spec={np.mean(fold_specs):.3f}')

rf_grid_df = pd.DataFrame(grid_results)
# Out:
#   n_est=100  depth=4      min_leaf=1    max_feat=sqrt   F1=0.446  acc=0.487  prec=0.494  rec=0.444  spec=0.562
#   n_est=100  depth=4      min_leaf=1    max_feat=log2   F1=0.446  acc=0.487  prec=0.494  rec=0.444  spec=0.562
#   n_est=100  depth=4      min_leaf=5    max_feat=sqrt   F1=0.461  acc=0.491  prec=0.531  rec=0.464  spec=0.543
#   n_est=100  depth=4      min_leaf=5    max_feat=log2   F1=0.461  acc=0.491  prec=0.531  rec=0.464  spec=0.543
#   n_est=100  depth=4      min_leaf=10   max_feat=sqrt   F1=0.457  acc=0.494  prec=0.524  rec=0.461  spec=0.554
#   n_est=100  depth=4      min_leaf=10   max_feat=log2   F1=0.457  acc=0.494  prec=0.524  rec=0.461  spec=0.554
#   n_est=100  depth=4      min_leaf=20   max_feat=sqrt   F1=0.457  acc=0.501  prec=0.540  rec=0.462  spec=0.567
#   n_est=100  depth=4      min_leaf=20   max_feat=log2   F1=0.457  acc=0.501  prec=0.540  rec=0.462  spec=0.567
#   n_est=100  depth=6      min_leaf=1    max_feat=sqrt   F1=0.456  acc=0.473  prec=0.512  rec=0.469  spec=0.505
#   n_est=100  depth=6      min_leaf=1    max_feat=log2   F1=0.456  acc=0.473  prec=0.512  rec=0.469  spec=0.505
#   n_est=100  depth=6      min_leaf=5    max_feat=sqrt   F1=0.476  acc=0.495  prec=0.536  rec=0.485  spec=0.534
#   n_est=100  depth=6      min_leaf=5    max_feat=log2   F1=0.476  acc=0.495  prec=0.536  rec=0.485  spec=0.534
#   n_est=100  depth=6      min_leaf=10   max_feat=sqrt   F1=0.450  acc=0.486  prec=0.517  rec=0.454  spec=0.543
#   n_est=100  depth=6      min_leaf=10   max_feat=log2   F1=0.450  acc=0.486  prec=0.517  rec=0.454  spec=0.543
#   n_est=100  depth=6      min_leaf=20   max_feat=sqrt   F1=0.457  acc=0.501  prec=0.540  rec=0.462  spec=0.567
#   n_est=100  depth=6      min_leaf=20   max_feat=log2   F1=0.457  acc=0.501  prec=0.540  rec=0.462  spec=0.567
#   n_est=100  depth=8      min_leaf=1    max_feat=sqrt   F1=0.465  acc=0.477  prec=0.513  rec=0.487  spec=0.495
#   n_est=100  depth=8      min_leaf=1    max_feat=log2   F1=0.465  acc=0.477  prec=0.513  rec=0.487  spec=0.495
#   n_est=100  depth=8      min_leaf=5    max_feat=sqrt   F1=0.477  acc=0.490  prec=0.534  rec=0.489  spec=0.517
#   n_est=100  depth=8      min_leaf=5    max_feat=log2   F1=0.477  acc=0.490  prec=0.534  rec=0.489  spec=0.517
#   n_est=100  depth=8      min_leaf=10   max_feat=sqrt   F1=0.451  acc=0.486  prec=0.517  rec=0.456  spec=0.541
#   n_est=100  depth=8      min_leaf=10   max_feat=log2   F1=0.451  acc=0.486  prec=0.517  rec=0.456  spec=0.541
#   n_est=100  depth=8      min_leaf=20   max_feat=sqrt   F1=0.457  acc=0.501  prec=0.540  rec=0.462  spec=0.567
#   n_est=100  depth=8      min_leaf=20   max_feat=log2   F1=0.457  acc=0.501  prec=0.540  rec=0.462  spec=0.567
#   n_est=100  depth=10     min_leaf=1    max_feat=sqrt   F1=0.466  acc=0.480  prec=0.523  rec=0.486  spec=0.504
#   n_est=100  depth=10     min_leaf=1    max_feat=log2   F1=0.466  acc=0.480  prec=0.523  rec=0.486  spec=0.504
#   n_est=100  depth=10     min_leaf=5    max_feat=sqrt   F1=0.473  acc=0.488  prec=0.529  rec=0.487  spec=0.515
#   n_est=100  depth=10     min_leaf=5    max_feat=log2   F1=0.473  acc=0.488  prec=0.529  rec=0.487  spec=0.515
#   n_est=100  depth=10     min_leaf=10   max_feat=sqrt   F1=0.451  acc=0.486  prec=0.518  rec=0.456  spec=0.542
#   n_est=100  depth=10     min_leaf=10   max_feat=log2   F1=0.451  acc=0.486  prec=0.518  rec=0.456  spec=0.542
#   n_est=100  depth=10     min_leaf=20   max_feat=sqrt   F1=0.457  acc=0.501  prec=0.540  rec=0.462  spec=0.567
#   n_est=100  depth=10     min_leaf=20   max_feat=log2   F1=0.457  acc=0.501  prec=0.540  rec=0.462  spec=0.567
#   n_est=100  depth=None   min_leaf=1    max_feat=sqrt   F1=0.465  acc=0.482  prec=0.519  rec=0.483  spec=0.511
#   n_est=100  depth=None   min_leaf=1    max_feat=log2   F1=0.465  acc=0.482  prec=0.519  rec=0.483  spec=0.511
#   n_est=100  depth=None   min_leaf=5    max_feat=sqrt   F1=0.473  acc=0.487  prec=0.528  rec=0.487  spec=0.512
#   n_est=100  depth=None   min_leaf=5    max_feat=log2   F1=0.473  acc=0.487  prec=0.528  rec=0.487  spec=0.512
#   n_est=100  depth=None   min_leaf=10   max_feat=sqrt   F1=0.451  acc=0.486  prec=0.518  rec=0.456  spec=0.542
#   n_est=100  depth=None   min_leaf=10   max_feat=log2   F1=0.451  acc=0.486  prec=0.518  rec=0.456  spec=0.542
#   n_est=100  depth=None   min_leaf=20   max_feat=sqrt   F1=0.457  acc=0.501  prec=0.540  rec=0.462  spec=0.567
#   n_est=100  depth=None   min_leaf=20   max_feat=log2   F1=0.457  acc=0.501  prec=0.540  rec=0.462  spec=0.567
#   n_est=200  depth=4      min_leaf=1    max_feat=sqrt   F1=0.438  acc=0.481  prec=0.508  rec=0.433  spec=0.562
#   n_est=200  depth=4      min_leaf=1    max_feat=log2   F1=0.438  acc=0.481  prec=0.508  rec=0.433  spec=0.562
#   n_est=200  depth=4      min_leaf=5    max_feat=sqrt   F1=0.449  acc=0.490  prec=0.529  rec=0.447  spec=0.561
#   n_est=200  depth=4      min_leaf=5    max_feat=log2   F1=0.449  acc=0.490  prec=0.529  rec=0.447  spec=0.561
#   n_est=200  depth=4      min_leaf=10   max_feat=sqrt   F1=0.455  acc=0.494  prec=0.537  rec=0.454  spec=0.563
#   n_est=200  depth=4      min_leaf=10   max_feat=log2   F1=0.455  acc=0.494  prec=0.537  rec=0.454  spec=0.563
#   n_est=200  depth=4      min_leaf=20   max_feat=sqrt   F1=0.446  acc=0.494  prec=0.552  rec=0.448  spec=0.569
#   n_est=200  depth=4      min_leaf=20   max_feat=log2   F1=0.446  acc=0.494  prec=0.552  rec=0.448  spec=0.569
#   n_est=200  depth=6      min_leaf=1    max_feat=sqrt   F1=0.459  acc=0.476  prec=0.512  rec=0.472  spec=0.509
#   n_est=200  depth=6      min_leaf=1    max_feat=log2   F1=0.459  acc=0.476  prec=0.512  rec=0.472  spec=0.509
#   n_est=200  depth=6      min_leaf=5    max_feat=sqrt   F1=0.462  acc=0.487  prec=0.526  rec=0.470  spec=0.533
#   n_est=200  depth=6      min_leaf=5    max_feat=log2   F1=0.462  acc=0.487  prec=0.526  rec=0.470  spec=0.533
#   n_est=200  depth=6      min_leaf=10   max_feat=sqrt   F1=0.465  acc=0.500  prec=0.539  rec=0.467  spec=0.560
#   n_est=200  depth=6      min_leaf=10   max_feat=log2   F1=0.465  acc=0.500  prec=0.539  rec=0.467  spec=0.560
#   n_est=200  depth=6      min_leaf=20   max_feat=sqrt   F1=0.446  acc=0.494  prec=0.552  rec=0.448  spec=0.569
#   n_est=200  depth=6      min_leaf=20   max_feat=log2   F1=0.446  acc=0.494  prec=0.552  rec=0.448  spec=0.569
#   n_est=200  depth=8      min_leaf=1    max_feat=sqrt   F1=0.453  acc=0.470  prec=0.502  rec=0.478  spec=0.492
#   n_est=200  depth=8      min_leaf=1    max_feat=log2   F1=0.453  acc=0.470  prec=0.502  rec=0.478  spec=0.492
#   n_est=200  depth=8      min_leaf=5    max_feat=sqrt   F1=0.461  acc=0.485  prec=0.526  rec=0.468  spec=0.530
#   n_est=200  depth=8      min_leaf=5    max_feat=log2   F1=0.461  acc=0.485  prec=0.526  rec=0.468  spec=0.530
#   n_est=200  depth=8      min_leaf=10   max_feat=sqrt   F1=0.466  acc=0.500  prec=0.538  rec=0.470  spec=0.559
#   n_est=200  depth=8      min_leaf=10   max_feat=log2   F1=0.466  acc=0.500  prec=0.538  rec=0.470  spec=0.559
#   n_est=200  depth=8      min_leaf=20   max_feat=sqrt   F1=0.446  acc=0.494  prec=0.552  rec=0.448  spec=0.569
#   n_est=200  depth=8      min_leaf=20   max_feat=log2   F1=0.446  acc=0.494  prec=0.552  rec=0.448  spec=0.569
#   n_est=200  depth=10     min_leaf=1    max_feat=sqrt   F1=0.465  acc=0.483  prec=0.525  rec=0.486  spec=0.510
#   n_est=200  depth=10     min_leaf=1    max_feat=log2   F1=0.465  acc=0.483  prec=0.525  rec=0.486  spec=0.510
#   n_est=200  depth=10     min_leaf=5    max_feat=sqrt   F1=0.467  acc=0.490  prec=0.526  rec=0.476  spec=0.530
#   n_est=200  depth=10     min_leaf=5    max_feat=log2   F1=0.467  acc=0.490  prec=0.526  rec=0.476  spec=0.530
#   n_est=200  depth=10     min_leaf=10   max_feat=sqrt   F1=0.466  acc=0.500  prec=0.538  rec=0.470  spec=0.559
#   n_est=200  depth=10     min_leaf=10   max_feat=log2   F1=0.466  acc=0.500  prec=0.538  rec=0.470  spec=0.559
#   n_est=200  depth=10     min_leaf=20   max_feat=sqrt   F1=0.446  acc=0.494  prec=0.552  rec=0.448  spec=0.569
#   n_est=200  depth=10     min_leaf=20   max_feat=log2   F1=0.446  acc=0.494  prec=0.552  rec=0.448  spec=0.569
#   n_est=200  depth=None   min_leaf=1    max_feat=sqrt   F1=0.456  acc=0.474  prec=0.505  rec=0.480  spec=0.501
#   n_est=200  depth=None   min_leaf=1    max_feat=log2   F1=0.456  acc=0.474  prec=0.505  rec=0.480  spec=0.501
#   n_est=200  depth=None   min_leaf=5    max_feat=sqrt   F1=0.466  acc=0.489  prec=0.528  rec=0.475  spec=0.530
#   n_est=200  depth=None   min_leaf=5    max_feat=log2   F1=0.466  acc=0.489  prec=0.528  rec=0.475  spec=0.530
#   n_est=200  depth=None   min_leaf=10   max_feat=sqrt   F1=0.466  acc=0.500  prec=0.538  rec=0.470  spec=0.559
#   n_est=200  depth=None   min_leaf=10   max_feat=log2   F1=0.466  acc=0.500  prec=0.538  rec=0.470  spec=0.559
#   n_est=200  depth=None   min_leaf=20   max_feat=sqrt   F1=0.446  acc=0.494  prec=0.552  rec=0.448  spec=0.569
#   n_est=200  depth=None   min_leaf=20   max_feat=log2   F1=0.446  acc=0.494  prec=0.552  rec=0.448  spec=0.569
#   n_est=500  depth=4      min_leaf=1    max_feat=sqrt   F1=0.444  acc=0.485  prec=0.513  rec=0.440  spec=0.560
#   n_est=500  depth=4      min_leaf=1    max_feat=log2   F1=0.444  acc=0.485  prec=0.513  rec=0.440  spec=0.560
#   n_est=500  depth=4      min_leaf=5    max_feat=sqrt   F1=0.456  acc=0.492  prec=0.529  rec=0.456  spec=0.555
#   n_est=500  depth=4      min_leaf=5    max_feat=log2   F1=0.456  acc=0.492  prec=0.529  rec=0.456  spec=0.555
#   n_est=500  depth=4      min_leaf=10   max_feat=sqrt   F1=0.451  acc=0.491  prec=0.524  rec=0.455  spec=0.557
#   n_est=500  depth=4      min_leaf=10   max_feat=log2   F1=0.451  acc=0.491  prec=0.524  rec=0.455  spec=0.557
#   n_est=500  depth=4      min_leaf=20   max_feat=sqrt   F1=0.447  acc=0.492  prec=0.515  rec=0.449  spec=0.564
#   n_est=500  depth=4      min_leaf=20   max_feat=log2   F1=0.447  acc=0.492  prec=0.515  rec=0.449  spec=0.564
#   n_est=500  depth=6      min_leaf=1    max_feat=sqrt   F1=0.454  acc=0.477  prec=0.509  rec=0.466  spec=0.516
#   n_est=500  depth=6      min_leaf=1    max_feat=log2   F1=0.454  acc=0.477  prec=0.509  rec=0.466  spec=0.516
#   n_est=500  depth=6      min_leaf=5    max_feat=sqrt   F1=0.470  acc=0.497  prec=0.535  rec=0.476  spec=0.545
#   n_est=500  depth=6      min_leaf=5    max_feat=log2   F1=0.470  acc=0.497  prec=0.535  rec=0.476  spec=0.545
#   n_est=500  depth=6      min_leaf=10   max_feat=sqrt   F1=0.455  acc=0.490  prec=0.531  rec=0.461  spec=0.548
#   n_est=500  depth=6      min_leaf=10   max_feat=log2   F1=0.455  acc=0.490  prec=0.531  rec=0.461  spec=0.548
#   n_est=500  depth=6      min_leaf=20   max_feat=sqrt   F1=0.447  acc=0.492  prec=0.515  rec=0.449  spec=0.564
#   n_est=500  depth=6      min_leaf=20   max_feat=log2   F1=0.447  acc=0.492  prec=0.515  rec=0.449  spec=0.564
#   n_est=500  depth=8      min_leaf=1    max_feat=sqrt   F1=0.470  acc=0.480  prec=0.520  rec=0.490  spec=0.498
#   n_est=500  depth=8      min_leaf=1    max_feat=log2   F1=0.470  acc=0.480  prec=0.520  rec=0.490  spec=0.498
#   n_est=500  depth=8      min_leaf=5    max_feat=sqrt   F1=0.472  acc=0.498  prec=0.537  rec=0.479  spec=0.545
#   n_est=500  depth=8      min_leaf=5    max_feat=log2   F1=0.472  acc=0.498  prec=0.537  rec=0.479  spec=0.545
#   n_est=500  depth=8      min_leaf=10   max_feat=sqrt   F1=0.456  acc=0.490  prec=0.533  rec=0.462  spec=0.548
#   n_est=500  depth=8      min_leaf=10   max_feat=log2   F1=0.456  acc=0.490  prec=0.533  rec=0.462  spec=0.548
#   n_est=500  depth=8      min_leaf=20   max_feat=sqrt   F1=0.447  acc=0.492  prec=0.515  rec=0.449  spec=0.564
#   n_est=500  depth=8      min_leaf=20   max_feat=log2   F1=0.447  acc=0.492  prec=0.515  rec=0.449  spec=0.564
#   n_est=500  depth=10     min_leaf=1    max_feat=sqrt   F1=0.465  acc=0.476  prec=0.503  rec=0.494  spec=0.487
#   n_est=500  depth=10     min_leaf=1    max_feat=log2   F1=0.465  acc=0.476  prec=0.503  rec=0.494  spec=0.487
#   n_est=500  depth=10     min_leaf=5    max_feat=sqrt   F1=0.471  acc=0.494  prec=0.531  rec=0.479  spec=0.535
#   n_est=500  depth=10     min_leaf=5    max_feat=log2   F1=0.471  acc=0.494  prec=0.531  rec=0.479  spec=0.535
#   n_est=500  depth=10     min_leaf=10   max_feat=sqrt   F1=0.456  acc=0.490  prec=0.534  rec=0.462  spec=0.548
#   n_est=500  depth=10     min_leaf=10   max_feat=log2   F1=0.456  acc=0.490  prec=0.534  rec=0.462  spec=0.548
#   n_est=500  depth=10     min_leaf=20   max_feat=sqrt   F1=0.447  acc=0.492  prec=0.515  rec=0.449  spec=0.564
#   n_est=500  depth=10     min_leaf=20   max_feat=log2   F1=0.447  acc=0.492  prec=0.515  rec=0.449  spec=0.564
#   n_est=500  depth=None   min_leaf=1    max_feat=sqrt   F1=0.462  acc=0.471  prec=0.497  rec=0.492  spec=0.478
#   n_est=500  depth=None   min_leaf=1    max_feat=log2   F1=0.462  acc=0.471  prec=0.497  rec=0.492  spec=0.478
#   n_est=500  depth=None   min_leaf=5    max_feat=sqrt   F1=0.471  acc=0.494  prec=0.533  rec=0.479  spec=0.537
#   n_est=500  depth=None   min_leaf=5    max_feat=log2   F1=0.471  acc=0.494  prec=0.533  rec=0.479  spec=0.537
#   n_est=500  depth=None   min_leaf=10   max_feat=sqrt   F1=0.456  acc=0.490  prec=0.534  rec=0.462  spec=0.548
#   n_est=500  depth=None   min_leaf=10   max_feat=log2   F1=0.456  acc=0.490  prec=0.534  rec=0.462  spec=0.548
#   n_est=500  depth=None   min_leaf=20   max_feat=sqrt   F1=0.447  acc=0.492  prec=0.515  rec=0.449  spec=0.564
#   n_est=500  depth=None   min_leaf=20   max_feat=log2   F1=0.447  acc=0.492  prec=0.515  rec=0.449  spec=0.564

# %%
print('Top 5 by F1:')
print(rf_grid_df.sort_values('f1', ascending=False).head().to_string(index=False))

print('\nTop 5 by Accuracy:')
print(rf_grid_df.sort_values('accuracy', ascending=False).head().to_string(index=False))

print('\nTop 5 by Precision:')
print(rf_grid_df.sort_values('precision', ascending=False).head().to_string(index=False))

print('\nTop 5 by Specificity:')
print(rf_grid_df.sort_values('specificity', ascending=False).head().to_string(index=False))

print('\nCurrent baseline (n_estimators=100):')
print(rf_grid_df[rf_grid_df['n_estimators'] == 100].to_string(index=False))
# Out:
# Top 5 by F1:
#  n_estimators  max_depth  min_samples_leaf max_features       f1  accuracy  precision   recall  specificity
#           100        8.0                 5         log2 0.476698  0.490476   0.533712 0.489437     0.516564
#           100        8.0                 5         sqrt 0.476698  0.490476   0.533712 0.489437     0.516564
#           100        6.0                 5         sqrt 0.476366  0.495238   0.535703 0.484694     0.533603
#           100        6.0                 5         log2 0.476366  0.495238   0.535703 0.484694     0.533603
#           100       10.0                 5         log2 0.473295  0.488312   0.529310 0.487232     0.514566
#
# Top 5 by Accuracy:
#  n_estimators  max_depth  min_samples_leaf max_features       f1  accuracy  precision   recall  specificity
#           100        8.0                20         log2 0.457295  0.501299   0.540219 0.461692     0.566533
#           100       10.0                20         log2 0.457295  0.501299   0.540219 0.461692     0.566533
#           100        6.0                20         log2 0.457295  0.501299   0.540219 0.461692     0.566533
#           100        6.0                20         sqrt 0.457295  0.501299   0.540219 0.461692     0.566533
#           100        NaN                20         log2 0.457295  0.501299   0.540219 0.461692     0.566533
#
# Top 5 by Precision:
#  n_estimators  max_depth  min_samples_leaf max_features       f1  accuracy  precision   recall  specificity
#           200        8.0                20         sqrt 0.446068  0.493939   0.552194 0.448292     0.569373
#           200       10.0                20         sqrt 0.446068  0.493939   0.552194 0.448292     0.569373
#           200        NaN                20         log2 0.446068  0.493939   0.552194 0.448292     0.569373
#           200        NaN                20         sqrt 0.446068  0.493939   0.552194 0.448292     0.569373
#           200        6.0                20         sqrt 0.446068  0.493939   0.552194 0.448292     0.569373
#
# Top 5 by Specificity:
#  n_estimators  max_depth  min_samples_leaf max_features       f1  accuracy  precision   recall  specificity
#           200       10.0                20         log2 0.446068  0.493939   0.552194 0.448292     0.569373
#           200        NaN                20         sqrt 0.446068  0.493939   0.552194 0.448292     0.569373
#           200        4.0                20         sqrt 0.445643  0.493506   0.551949 0.447501     0.569373
#           200        4.0                20         log2 0.445643  0.493506   0.551949 0.447501     0.569373
#           200        6.0                20         sqrt 0.446068  0.493939   0.552194 0.448292     0.569373
#
# Current baseline (n_estimators=100):
#  n_estimators  max_depth  min_samples_leaf max_features       f1  accuracy  precision   recall  specificity
#           100        4.0                 1         sqrt 0.445509  0.487446   0.494484 0.444122     0.562082
#           100        4.0                 1         log2 0.445509  0.487446   0.494484 0.444122     0.562082
#           100        4.0                 5         sqrt 0.461035  0.490909   0.530687 0.463903     0.542576
#           100        4.0                 5         log2 0.461035  0.490909   0.530687 0.463903     0.542576
#           100        4.0                10         sqrt 0.457290  0.493939   0.524437 0.460789     0.554115
#           100        4.0                10         log2 0.457290  0.493939   0.524437 0.460789     0.554115
#           100        4.0                20         sqrt 0.457295  0.501299   0.540219 0.461692     0.566533
#           100        4.0                20         log2 0.457295  0.501299   0.540219 0.461692     0.566533
#           100        6.0                 1         sqrt 0.456330  0.473160   0.511651 0.469035     0.505092
#           100        6.0                 1         log2 0.456330  0.473160   0.511651 0.469035     0.505092
#           100        6.0                 5         sqrt 0.476366  0.495238   0.535703 0.484694     0.533603
#           100        6.0                 5         log2 0.476366  0.495238   0.535703 0.484694     0.533603
#           100        6.0                10         sqrt 0.450459  0.485714   0.517094 0.454434     0.543329
#           100        6.0                10         log2 0.450459  0.485714   0.517094 0.454434     0.543329
#           100        6.0                20         sqrt 0.457295  0.501299   0.540219 0.461692     0.566533
#           100        6.0                20         log2 0.457295  0.501299   0.540219 0.461692     0.566533
#           100        8.0                 1         sqrt 0.464862  0.476623   0.513091 0.487136     0.494541
#           100        8.0                 1         log2 0.464862  0.476623   0.513091 0.487136     0.494541
#           100        8.0                 5         sqrt 0.476698  0.490476   0.533712 0.489437     0.516564
#           100        8.0                 5         log2 0.476698  0.490476   0.533712 0.489437     0.516564
#           100        8.0                10         sqrt 0.451303  0.485714   0.517291 0.456160     0.541403
#           100        8.0                10         log2 0.451303  0.485714   0.517291 0.456160     0.541403
#           100        8.0                20         sqrt 0.457295  0.501299   0.540219 0.461692     0.566533
#           100        8.0                20         log2 0.457295  0.501299   0.540219 0.461692     0.566533
#           100       10.0                 1         sqrt 0.466086  0.479654   0.523036 0.485729     0.503971
#           100       10.0                 1         log2 0.466086  0.479654   0.523036 0.485729     0.503971
#           100       10.0                 5         sqrt 0.473295  0.488312   0.529310 0.487232     0.514566
#           100       10.0                 5         log2 0.473295  0.488312   0.529310 0.487232     0.514566
#           100       10.0                10         sqrt 0.451496  0.486147   0.518099 0.456160     0.542161
#           100       10.0                10         log2 0.451496  0.486147   0.518099 0.456160     0.542161
#           100       10.0                20         sqrt 0.457295  0.501299   0.540219 0.461692     0.566533
#           100       10.0                20         log2 0.457295  0.501299   0.540219 0.461692     0.566533
#           100        NaN                 1         sqrt 0.465131  0.481818   0.519130 0.483078     0.510947
#           100        NaN                 1         log2 0.465131  0.481818   0.519130 0.483078     0.510947
#           100        NaN                 5         sqrt 0.472511  0.487013   0.528023 0.486806     0.512472
#           100        NaN                 5         log2 0.472511  0.487013   0.528023 0.486806     0.512472
#           100        NaN                10         sqrt 0.451496  0.486147   0.518099 0.456160     0.542161
#           100        NaN                10         log2 0.451496  0.486147   0.518099 0.456160     0.542161
#           100        NaN                20         sqrt 0.457295  0.501299   0.540219 0.461692     0.566533
#           100        NaN                20         log2 0.457295  0.501299   0.540219 0.461692     0.566533
